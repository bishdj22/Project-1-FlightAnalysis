# %%
# modules
import os
import pandas as pd
import csv 


#import data from spread sheet 
faa_data = pd.read_csv(faa_data)
faa_data.head()
# Out:
#    year   month carrier       carrier_name airport  \
# 0  2019       9      9E  Endeavor Air Inc.     ABE
# 1  2019       9      9E  Endeavor Air Inc.     ACK
# 2  2019       9      9E  Endeavor Air Inc.     AEX
# 3  2019       9      9E  Endeavor Air Inc.     AGS
# 4  2019       9      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         54.0        4.0
# 1                  Nantucket, MA: Nantucket Memorial          1.0        0.0
# 2           Alexandria, LA: Alexandria International        105.0        6.0
# 3        Augusta, GA: Augusta Regional at Bush Field        130.0       13.0
# 4                   Albany, NY: Albany International         23.0        2.0
#
#    carrier_ct   weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.57         0.00  ...          0.0              0.93            0.0
# ...

# %%
count = faa_data["carrier_name"].value_counts()
count
# Out:
# SkyWest Airlines Inc.      250
# Envoy Air                  149
# Delta Air Lines Inc.       144
# Mesa Airlines Inc.         112
# Allegiant Air              110
# United Air Lines Inc.      107
# American Airlines Inc.     106
# Frontier Airlines Inc.     102
# Endeavor Air Inc.           99
# Republic Airline            92
# PSA Airlines Inc.           90
# Southwest Airlines Co.      88
# ExpressJet Airlines LLC     84
# Alaska Airlines Inc.        72
# JetBlue Airways             67
# Spirit Air Lines            50
# Hawaiian Airlines Inc.      19
# Name: carrier_name, dtype: int64

# %%
count=faa_data["arr_flights"].value_counts()
count
# Out:
# 60.0     72
# 30.0     64
# 56.0     31
# 9.0      24
# 18.0     23
#          ..
# 434.0     1
# 125.0     1
# 380.0     1
# 808.0     1
# 427.0     1
# Name: arr_flights, Length: 566, dtype: int64
