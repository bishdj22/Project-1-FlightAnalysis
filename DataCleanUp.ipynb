# %%
# Import Dependencies
import pandas as pd

# %%
# File to Load
file_path = "./Data/airline_delay_causes.csv"
# Read file into Pandas DataFrame
original_data = pd.read_csv(file_path)

original_data.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2018       9      F9  Frontier Airlines Inc.     PBI
# 1  2018       9      F9  Frontier Airlines Inc.     PDX
# 2  2018       9      F9  Frontier Airlines Inc.     PHL
# 3  2018       9      F9  Frontier Airlines Inc.     PHX
# 4  2018       9      F9  Frontier Airlines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...          8.0        3.0
# 1               Portland, OR: Portland International         69.0       24.0
# 2       Philadelphia, PA: Philadelphia International        321.0      113.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International        103.0       25.0
# 4           Pittsburgh, PA: Pittsburgh International         32.0        9.0
#
#    carrier_ct   weather_ct  ...  late_aircraft_ct  arr_cancelled  \
# 0        0.85          0.0  ...              1.65            0.0
# ...

# %%
original_data = original_data.drop(columns=['Unnamed: 21'])
original_data.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2018       9      F9  Frontier Airlines Inc.     PBI
# 1  2018       9      F9  Frontier Airlines Inc.     PDX
# 2  2018       9      F9  Frontier Airlines Inc.     PHL
# 3  2018       9      F9  Frontier Airlines Inc.     PHX
# 4  2018       9      F9  Frontier Airlines Inc.     PIT
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...          8.0        3.0
# 1               Portland, OR: Portland International         69.0       24.0
# 2       Philadelphia, PA: Philadelphia International        321.0      113.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International        103.0       25.0
# 4           Pittsburgh, PA: Pittsburgh International         32.0        9.0
#
#    carrier_ct   weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        0.85          0.0  ...          0.0              1.65            0.0
# ...

# %%
original_data = original_data.rename(columns = {"arr_flights" : "Total Number Flights", "carrier_ct" : "Air Carrier Delayed (flights)",
                                               "weather_ct" : "Weather Delayed (flights)", "nas_ct": "National Aviation System Delay (flights)",
                                               "security_ct" : "Security Delay (flights)", "late_aircraft_ct" : "Aircraft Arriving Late (flights)",
                                               "arr_cancelled" : "Cancelled (flights)", "arr_diverted" : "Diverted (flights)", "arr_delay" : "Total Delayed Minutes",
                                               "carrier_delay" : "Air Carrier Delayed (minutes)", "weather_delay" : "Weather Delayed (minutes)", 
                                               "nas_delay": "National Aviation System Delay (minutes)", "security_delay" : "Security Delay (minutes)", 
                                               "late_aircraft_delay" : "Aircraft Arriving Late (minutes)"})

original_data.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2018       9      F9  Frontier Airlines Inc.     PBI
# 1  2018       9      F9  Frontier Airlines Inc.     PDX
# 2  2018       9      F9  Frontier Airlines Inc.     PHL
# 3  2018       9      F9  Frontier Airlines Inc.     PHX
# 4  2018       9      F9  Frontier Airlines Inc.     PIT
#
#                                         airport_name  Total Number Flights  \
# 0  West Palm Beach/Palm Beach, FL: Palm Beach Int...                   8.0
# 1               Portland, OR: Portland International                  69.0
# 2       Philadelphia, PA: Philadelphia International                 321.0
# 3      Phoenix, AZ: Phoenix Sky Harbor International                 103.0
# 4           Pittsburgh, PA: Pittsburgh International                  32.0
#
#    arr_del15  Air Carrier Delayed (flights)   weather_ct  ...  \
# 0        3.0                           0.85          0.0  ...
# ...
